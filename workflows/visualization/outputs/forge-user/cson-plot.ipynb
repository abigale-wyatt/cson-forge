# %% [markdown]
# # Plot CSON

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.colors as colors

import cartopy
import cartopy.crs as ccrs

import cmocean

import roms_tools as rt
from cson_forge import catalog

# %%
df = catalog.blueprint.load(stage="postconfig")
df
# Out:
#              model_name  grid_name                  blueprint_name  \
# 0  cson_roms-marbl_v0.1   ccs-12km   cson_roms-marbl_v0.1_ccs-12km
# 1  cson_roms-marbl_v0.1  test-tiny  cson_roms-marbl_v0.1_test-tiny
#
#                  description           start_time             end_time  \
# 0  California Current System  2024-01-01T00:00:00  2024-01-02T00:00:00
# 1                  Test tiny  2012-01-01T00:00:00  2012-01-02T00:00:00
#
#                                       blueprint_path  \
# 0  /Users/mclong/codes/cson-forge/cson_forge/blue...
# 1  /Users/mclong/codes/cson-forge/cson_forge/blue...
#
#                                       grid_yaml_path       stage
# 0  /Users/mclong/codes/cson-forge/cson_forge/blue...  postconfig
# 1  /Users/mclong/codes/cson-forge/cson_forge/blue...  postconfig

# %%
grids = {}
for _, row in df.iterrows():
    name = row["grid_name"]
    grid_yaml_path = row["grid_yaml_path"]
    grids[name] = rt.Grid.from_yaml(grid_yaml_path)

# %%
prj = ccrs.Robinson(central_longitude=305.0)

fig, ax = plt.subplots(
    figsize=(12, 12),
    facecolor='k',
    subplot_kw=dict(projection=prj),
)

ocean = ax.add_feature(
    cartopy.feature.NaturalEarthFeature(
        'physical','ocean','110m',
        edgecolor='face',
        facecolor='#749EB0',
        zorder=-9999,
    )
)

land = ax.add_feature(
     cartopy.feature.NaturalEarthFeature(
         'physical','land','110m',
         edgecolor='face',
         facecolor='#355560'
     )
 )

ax.coastlines()

ax.spines['geo'].set_visible(True)
ax.spines['geo'].set_linewidth(2)
ax.spines['geo'].set_edgecolor('black')

for g in grids.values():
    ax.pcolormesh(
        g.ds.lon_rho, g.ds.lat_rho, g.ds.h, 
        #edgecolors='k', linewidth=0.25,
        transform=ccrs.PlateCarree(),
        cmap=cmocean.cm.deep,
    )
    
ax.set_global() # For a global map

fig_size = (16, 9)
fig.set_size_inches(fig_size)
fig.tight_layout()

fig.savefig('../../assets/cson.png', dpi=300, transparent=True)

# %%
for name, g in grids.items():
    rt.plot.plot(g.ds.h, g.ds) # , ax=ax) passing an axis is broken https://github.com/CWorthy-ocean/roms-tools/issues/489
    plt.gca().set_title(name)
