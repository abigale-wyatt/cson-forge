# %% [markdown]
# # Making a new domain: `CStarSpecBuilder`
#
# This notebook demonstrates how to create a new domain and run a ROMS simulation using C-SON Forge.

# %% [markdown]
# ## Setup
#
# First, import the necessary modules and define the domain configuration parameters.

# %%
# %load_ext autoreload
# %autoreload 2

import cson_forge
import cstar.execution.handler as handler
import time
from datetime import datetime
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /anvil/projects/x-ees250129/x-awyatt1/.conda-env/share/proj failed

# %%
grid_name_inner = "GoA-p10"

grid_kwargs_inner = dict[str, float](
    nx=208,
    ny=192,
    size_x=1460,   # km (longitude direction at ~49N)
    size_y=2350,   # km (latitude direction)
    center_lon=-139.5,
    center_lat=53,
    rot=41,
    N=10,  # number of vertical levels
    theta_s=6.0,  # surface control parameter
    theta_b=3.0,  # bottom control parameter
    hc=250.0,  # critical depth
)

boundaries_inner={
        "south": True,
        "east": False,
        "north": True,
        "west": True, 
    }

# %%
grid_name_middle = "NEP-p25"

grid_kwargs_middle = dict[str, float](
    nx=208,
    ny=192,
    size_x=1460*2.5,   # km (longitude direction at ~49N)
    size_y=2220*2.5,   # km (latitude direction)
    center_lon=-140,
    center_lat=40,
    rot=43,
    N=10,  # number of vertical levels
    theta_s=6.0,  # surface control parameter
    theta_b=3.0,  # bottom control parameter
    hc=250.0,  # critical depth
)

boundaries_middle={
        "south": True,
        "east": False,
        "north": True,
        "west": True, 
    }

# %%
grid_name_outer = "PAC-0p5"

grid_kwargs_outer = dict[str, float](
    nx=208,
    ny=192,
    size_x=1460*5,   # km (longitude direction at ~49N)
    size_y=2220*5,   # km (latitude direction)
    center_lon=-165,
    center_lat=40,
    rot=-90,
    N=10,  # number of vertical levels
    theta_s=6.0,  # surface control parameter
    theta_b=3.0,  # bottom control parameter
    hc=250.0,  # critical depth
)

boundaries_outer={
        "south": True,
        "east": True,
        "north": True,
        "west": True, 
    }

# %%
model_name = "cson_roms-marbl_v0.1"
start_time = datetime(2010, 1, 1)
end_time = datetime(2025, 1, 1)

partitioning = {
    "n_procs_x": 16, # number of partitions in xi (x) 
    "n_procs_y": 8, # number of partitions in eta (y) 
}

# %% [markdown]
# ## Initialize CstarSpecBuilder
#
# Create a `CstarSpecBuilder` instance with the domain configuration. This initializes the PRECONFIG stage, creating the grid object and blueprint structure.

# %%
ocn_inner = cson_forge.CstarSpecBuilder(
    description="GoA p10 toy",
    model_name=model_name,
    grid_name=grid_name_inner,
    grid_kwargs_parent=grid_kwargs_middle,
    grid_kwargs=grid_kwargs_inner,
    open_boundaries=boundaries_inner,    
    start_time=start_time,
    end_time=end_time,
    partitioning=partitioning,
)

ocn_middle = cson_forge.CstarSpecBuilder(
    description="NEP p25 toy",
    model_name=model_name,
    grid_name=grid_name_middle,
    grid_kwargs_parent=grid_kwargs_outer,
    grid_kwargs=grid_kwargs_middle,
    open_boundaries=boundaries_middle,    
    start_time=start_time,
    end_time=end_time,
    partitioning=partitioning,
)

ocn_outer = cson_forge.CstarSpecBuilder(
    description="PAC 0p5 toy",
    model_name=model_name,
    grid_name=grid_name_outer,
    grid_kwargs=grid_kwargs_outer,
    open_boundaries=boundaries_outer,    
    start_time=start_time,
    end_time=end_time,
    partitioning=partitioning,
)

# %% [markdown]
# ### Visualize the grid

# %%
ocn_inner.grid.plot()
ocn_middle.grid.plot()
ocn_outer.grid.plot()

# %% [markdown]
# ## Prepare Source Data
#
# Ensure that all required source datasets (GLORYS, UNIFIED, SRTM15, etc.) are staged locally. This downloads and prepares the data needed for input generation.

# %%
# ensure that source data is staged locally

# ocn_inner.ensure_source_data()
# ocn_middle.ensure_source_data()
ocn_outer.ensure_source_data()
# Out:
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100101.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100102.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100103.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100104.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100105.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100106.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100107.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100108.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100109.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100110.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100111.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100112.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100113.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100114.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100115.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100116.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100117.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100118.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100119.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100120.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100121.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100122.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100123.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100124.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100125.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100126.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100127.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100128.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100129.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100130.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-01-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100131.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100201.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100202.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100203.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100204.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100205.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100206.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100207.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100208.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100209.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100210.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100211.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100212.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100213.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100214.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100215.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100216.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100217.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100218.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100219.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100220.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100221.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100222.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100223.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100224.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100225.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100226.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100227.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-02-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100228.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100301.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100302.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100303.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100304.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100305.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100306.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100307.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100308.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100309.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100310.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100311.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100312.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100313.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100314.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100315.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100316.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100317.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100318.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100319.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100320.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100321.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100322.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100323.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100324.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100325.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100326.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100327.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100328.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100329.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100330.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-03-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100331.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100401.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100402.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100403.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100404.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100405.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100406.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100407.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100408.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100409.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100410.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100411.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100412.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100413.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100414.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100415.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100416.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100417.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100418.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100419.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100420.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100421.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100422.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100423.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100424.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100425.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100426.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100427.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100428.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100429.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-04-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100430.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100501.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100502.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100503.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100504.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100505.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100506.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100507.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100508.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100509.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100510.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100511.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100512.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100513.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100514.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100515.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100516.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100517.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100518.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100519.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100520.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100521.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100522.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100523.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100524.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100525.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100526.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100527.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100528.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100529.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100530.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-05-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100531.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100601.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100602.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100603.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100604.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100605.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100606.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100607.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100608.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100609.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100610.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100611.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100612.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100613.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100614.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100615.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100616.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100617.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100618.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100619.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100620.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100621.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100622.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100623.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100624.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100625.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100626.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100627.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100628.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100629.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-06-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100630.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100701.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100702.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100703.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100704.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100705.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100706.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100707.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100708.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100709.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100710.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100711.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100712.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100713.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100714.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100715.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100716.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100717.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100718.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100719.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100720.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100721.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100722.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100723.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100724.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100725.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100726.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100727.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100728.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100729.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100730.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-07-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100731.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100801.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100802.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100803.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100804.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100805.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100806.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100807.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100808.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100809.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100810.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100811.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100812.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100813.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100814.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100815.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100816.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100817.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100818.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100819.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100820.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100821.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100822.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100823.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100824.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100825.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100826.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100827.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100828.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100829.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100830.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-08-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100831.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100901.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100902.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100903.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100904.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100905.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100906.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100907.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100908.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100909.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100910.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100911.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100912.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100913.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100914.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100915.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100916.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100917.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100918.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100919.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100920.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100921.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100922.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100923.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100924.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100925.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100926.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100927.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100928.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100929.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-09-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20100930.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101001.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101002.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101003.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101004.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101005.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101006.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101007.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101008.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101009.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101010.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101011.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101012.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101013.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101014.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101015.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101016.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101017.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101018.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101019.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101020.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101021.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101022.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101023.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101024.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101025.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101026.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101027.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101028.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101029.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101030.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-10-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101031.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101101.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101102.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101103.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101104.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101105.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101106.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101107.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101108.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101109.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101110.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101111.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101112.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101113.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101114.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101115.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101116.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101117.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101118.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101119.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101120.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101121.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101122.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101123.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101124.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101125.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101126.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101127.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101128.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101129.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-11-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101130.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101201.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101202.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101203.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101204.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101205.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101206.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101207.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101208.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101209.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101210.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101211.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101212.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101213.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101214.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101215.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101216.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101217.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101218.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101219.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101220.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101221.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101222.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101223.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101224.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101225.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101226.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101227.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101228.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101229.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101230.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2010-12-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20101231.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110101.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110102.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110103.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110104.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110105.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110106.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110107.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110108.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110109.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110110.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110111.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110112.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110113.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110114.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110115.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110116.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110117.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110118.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110119.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110120.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110121.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110122.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110123.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110124.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110125.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110126.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110127.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110128.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110129.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110130.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-01-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110131.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110201.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110202.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110203.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110204.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110205.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110206.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110207.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110208.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110209.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110210.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110211.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110212.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110213.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110214.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110215.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110216.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110217.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110218.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110219.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110220.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110221.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110222.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110223.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110224.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110225.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110226.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110227.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-02-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110228.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110301.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110302.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110303.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110304.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110305.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110306.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110307.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110308.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110309.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110310.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110311.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110312.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110313.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110314.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110315.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2011-03-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20110316.nc
# ...
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240811.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240812.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240813.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240814.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240815.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240816.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240817.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240818.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240819.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240820.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240821.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240822.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240823.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240824.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240825.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240826.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240827.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240828.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240829.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240830.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-08-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240831.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240901.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240902.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240903.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240904.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240905.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240906.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240907.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240908.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240909.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240910.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240911.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240912.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240913.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240914.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240915.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240916.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240917.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240918.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240919.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240920.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240921.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240922.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240923.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240924.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240925.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240926.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240927.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240928.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240929.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-09-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20240930.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241001.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241002.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241003.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241004.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241005.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241006.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241007.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241008.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241009.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241010.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241011.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241012.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241013.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241014.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241015.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241016.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241017.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241018.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241019.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241020.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241021.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241022.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241023.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241024.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241025.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241026.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241027.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241028.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241029.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241030.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-10-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241031.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241101.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241102.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241103.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241104.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241105.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241106.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241107.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241108.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241109.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241110.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241111.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241112.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241113.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241114.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241115.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241116.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241117.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241118.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241119.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241120.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241121.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241122.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241123.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241124.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241125.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241126.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241127.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241128.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241129.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-11-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241130.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241201.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241202.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241203.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-04: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241204.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-05: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241205.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-06: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241206.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-07: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241207.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-08: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241208.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-09: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241209.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-10: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241210.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-11: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241211.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-12: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241212.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-13: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241213.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-14: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241214.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-15: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241215.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-16: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241216.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-17: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241217.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-18: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241218.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-19: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241219.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-20: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241220.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-21: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241221.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-22: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241222.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-23: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241223.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-24: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241224.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-25: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241225.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-26: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241226.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-27: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241227.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-28: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241228.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-29: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241229.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-30: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241230.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2024-12-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20241231.nc
# ✔️  Using existing GLORYS_GLOBAL file for 2025-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20250101.nc
# ✔️  TPXO dataset verified at: /anvil/projects/x-ees250129/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /anvil/projects/x-ees250129/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc

# %% [markdown]
# ## Generate Input Files
#
# Generate all model input files (grid, initial conditions, forcing) from the source data. This completes the POSTCONFIG stage and updates the blueprint with actual file paths.
#
# The system will look for an existing blueprint and, if a match is found, it will use that data unless the user sets `clobber=True` to force re-generating the data.

# %%
# prepare model input
# ocn_inner.generate_inputs(clobber=False) # setting clobber=True will overwrite existing files
# ocn_middle.generate_inputs(clobber=False) # setting clobber=True will overwrite existing files
ocn_outer.generate_inputs(clobber=False) # setting clobber=True will overwrite existing files
# Out:
# ▶️  [1/8] Writing ROMS grid...
#
# ▶️  [2/8] Generating initial conditions...
# [########################################] | 100% Completed | 79.09 ss
#
# ▶️  [3/8] Generating surface forcing...

# %% [markdown]
# ## Access Generated Input Datasets
#
# Input datasets are available on the `datasets` attribute of the `CstarSpecBuilder` after `generate_inputs()` has completed. The `datasets` dictionary only contains keys for fields that exist in the blueprint and have been successfully generated.
#
# **Note:** Datasets are only available after `generate_inputs()` has run and populated the blueprint with actual file paths. If a key doesn't exist, it means that field wasn't generated or isn't in the blueprint.

# %%
for ocn in [ocn_inner,ocn_middle,ocn_outer]:
    for key in ocn.datasets.keys():
        print("-"*100)
        print(key)
        print(ocn.datasets[key])

# %% [markdown]
# ## Configure Build
#
# Render the Jinja2 templates to generate compile-time and run-time configuration files (`.opt` files, `roms.in`, etc.). This prepares the BUILD stage.

# %%
# configure and build the model
for ocn in [ocn_inner,ocn_middle,ocn_outer]:
    ocn.configure_build(compile_time_settings={}, run_time_settings={})

# %% [markdown]
# ## Build Model Executable
#
# Compile the ROMS/MARBL model source code to create the executable. This uses the C-Star build system to compile the model with the specified configuration.

# %%
for ocn in [ocn_inner,ocn_middle,ocn_outer]:
    ocn.build()
# Out:
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# [WARNING] Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10

# %% [markdown]
# ## Pre-Run Setup
#
# Perform pre-run operations, including partitioning input files for parallel execution if needed.

# %%
# perform partitioning

for ocn in [ocn_inner,ocn_middle,ocn_outer]:
    ocn.pre_run()

# %% [markdown]
# ## Run Model Simulation
#
# Execute the ROMS model simulation. This runs the model with the configured inputs and settings.

# %%
# run the model
for ocn in [ocn_inner,ocn_middle,ocn_outer]:
    exec_handler = ocn.run()
    print(exec_handler)
# Out:
# [INFO] Running srun -n 1 /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/compile_time_code/roms /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/runtime_code/cson_roms-marbl_v0.1_test-tiny-abigale.in
# LocalProcess
# ------------
# Commands: srun -n 1 /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/compile_time_code/roms /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/runtime_code/cson_roms-marbl_v0.1_test-tiny-abigale.in
# Run path: /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/output
# Output file: /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/logs/cson_roms-marbl_v0-1_test-tiny-abigale.out
# Status: running

# %%
# %%time

while not handler.ExecutionStatus.is_terminal(exec_handler.status):
    print("...", end="", flush=True)
    time.sleep(30)

if exec_handler.status == handler.ExecutionStatus.COMPLETED:
    print()
    print("Completed")
    ocn.post_run()
else:
    raise Exception("Model run failed")
# Out:
# CPU times: user 347 μs, sys: 4 μs, total: 351 μs
# Wall time: 262 μs
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\nwhile not handler.ExecutionStatus.is_terminal(exec_handler.status):\n    print("...", end="", flush=True)\n    time.sleep(30)\n\nif exec_handler.status == handler.ExecutionStatus.COMPLETED:\n    print()\n    print("Completed")\n    ocn.post_run()\nelse:\n    raise Exception("Model run failed")\n')
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1447, in ExecutionMagics.time(self, line, cell, local_ns)
#    1445 if interrupt_occured:
#    1446     if exit_on_interrupt and captured_exception:
# -> 1447         raise captured_exception
#    1448     return
#    1449 return out
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1411, in ExecutionMagics.time(self, line, cell, local_ns)
#    1409 st = clock2()
#    1410 try:
# -> 1411     exec(code, glob, local_ns)
#    1412     out = None
#    1413     # multi-line %%time case
#
# File <timed exec>:10
#
# Exception: Model run failed

# %% [markdown]
# ## Visualize Model Output
#
# After the model run completes, you can load and visualize the output data. The code below:
#
# 1. **Finds output files**: Uses `glob` to locate all BGC (biogeochemical) output files in the `JOINED_OUTPUT` directory
# 2. **Opens the dataset**: Uses `xarray.open_mfdataset()` to open multiple NetCDF files as a single dataset
# 3. **Applies land mask**: Masks out land points using the grid's `mask_rho` variable
# 4. **Plots a variable**: Creates a plot of dissolved inorganic carbon (DIC) at the first time step and bottom vertical level (`s_rho=-1`)
#
# The `JOINED_OUTPUT` directory contains the spatially-joined output files created by `post_run()`, which combine partitioned output files from parallel runs into single files.

# %%
import xarray as xr
from glob import glob

files = glob(str(ocn.run_output_dir / "JOINED_OUTPUT" / (ocn.casename + "_bgc.*")))
ds = xr.open_mfdataset(files)
ds = ds.where(ocn.grid.ds.mask_rho)
ds.DIC.isel(time=0, s_rho=-1).plot()

# %% [markdown]
# ## Set Blueprint State
#
# The `set_blueprint_state()` method updates the state of the blueprint, which tracks the workflow stage of the simulation specification. Blueprint states indicate the current stage of the workflow (e.g., "draft", "configured", "ready") and are used by the C-Star orchestration system to manage the simulation lifecycle.
#
# Common blueprint states include:
# - `"draft"`: The blueprint is in development and not yet finalized
# - `"validated"`: The blueprint has been validated
#
# Setting the state to `"draft"` is useful when you want to mark the blueprint as a work-in-progress that may need further modifications before execution.

# %%
ocn.set_blueprint_state(state="draft")
